# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
timestamp_format='%Y-%m-%d %H:%M:%S'
raw_sensor_data=[]
device_types=list(DEVICE_TYPES)
locations=list(LOCATIONS)
reading_ranges=dict(READING_RANGES)
for i in range(100):
    timestamp=datetime.datetime.now().strftime(timestamp_format)
    device_id=f'DEV{i+1:03d}'
    device_type=random.choice(device_types)
    location=random.choice(locations)
    min_val, max_val = reading_ranges[device_type]
    value = round(random.uniform(min_val, max_val), 2)
    raw_sensor_data.append((timestamp,device_id,device_type,location,value))




# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = []
for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading
    if device_type == 'Temperature_Sensor':
        temperature_readings.append({
            'timestamp': timestamp,
            'device_id': device_id,
            'location': location,
            'temperature_celsius': value
        })

print(f"Generated {len(temperature_readings)} temperature readings.")
# Display the first 5 temperature readings for verification
print("First 5 temperature readings:")
for i in range(min(5, len(temperature_readings))):
    print(temperature_readings[i])



# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()
for reading in raw_sensor_data:
    # The location is the fourth element (index 3) in the tuple
    location = reading[3]
    unique_locations.add(location)

print(f"Unique locations: {unique_locations}")
print(f"Number of unique locations: {len(unique_locations)}")

# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {}

for reading in raw_sensor_data:
    _, _, device_type, _, value = reading

    if device_type not in device_stats:
        # Initialize with sensible large/small values for min and max
        device_stats[device_type] = (float('inf'), float('-inf'))

    current_min, current_max = device_stats[device_type]
    device_stats[device_type] = (min(current_min, value), max(current_max, value))

print("Device Statistics (min_value, max_value):")
for device_type, (min_val, max_val) in device_stats.items():
    print(f"  {device_type}: Min={min_val:.2f}, Max={max_val:.2f}")



# 1.5: Advanced Indexing and Slicing (Lists and Strings)
first_10_raw_readings = raw_sensor_data[0:10]
print("\nFirst 10 raw sensor readings:")
for reading in first_10_raw_readings:
    print(reading)

# 1.5.2 Getting the device_type of the 5th reading (index 4) from raw_sensor_data
fifth_reading_device_type = raw_sensor_data[4][2]
print(f"\nDevice type of the 5th reading: {fifth_reading_device_type}")

# 1.5.3 Accessing the temperature value from the second item (index 1) in 'temperature_readings'
if len(temperature_readings) > 1:
    second_temp_reading_value = temperature_readings[1]['temperature_celsius']
    print(f"\nTemperature value of the second recorded temperature reading: {second_temp_reading_value}")
else:
    print("\nNot enough temperature readings to demonstrate accessing the second item.")

# 1.5.4 Slicing a timestamp string (e.g., to get only the date part)
if raw_sensor_data:
    sample_timestamp = raw_sensor_data[0][0] # Get timestamp from the first reading
    date_part = sample_timestamp[0:10] # 'YYYY-MM-DD'
    time_part = sample_timestamp[11:19] # 'HH:MM:SS'
    print(f"\nOriginal timestamp: {sample_timestamp}")
    print(f"Date part: {date_part}")
    print(f"Time part: {time_part}")
else:
    print("\nNo raw sensor data available to demonstrate timestamp slicing.")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:

sliced_readings_1 = raw_sensor_data[9:21]
print("\nSliced Readings 1 (10th to 20th inclusive):")
for reading in sliced_readings_1:
    print(reading)

# Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
sliced_readings_2 = raw_sensor_data[::5]
print("\nSliced Readings 2 (every 5th reading):")
for reading in sliced_readings_2:
    print(reading)

# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
sample_string = "Python Programming is fun and powerful."
print(f"\nOriginal string: '{sample_string}'")

# 1.5.2 String Slicing: Extract the substring "Programming"
substring_1 = sample_string[7:18] # 'Programming' starts at index 7 and ends at index 17 (exclusive of 18)
print(f"Extracted 'Programming': '{substring_1}'")

# Then, extract the substring "nohtyP" (the reverse of "Python") using slicing.
# 'Python' is at indices 0-5. To reverse it, we can slice it first and then reverse.
python_word = sample_string[0:6]
substring_2 = python_word[::-1]
print(f"Extracted reversed 'Python' ('nohtyP'): '{substring_2}'")


# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:

print(f"\nDevice type of the 5th reading (from previous step): {fifth_reading_device_type}")

# Then, from 'fifth_reading_device_type', extract the last 6 characters.
device_type_suffix = fifth_reading_device_type[-6:]
print(f"Extracted device type suffix: '{device_type_suffix}'")


# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
print("\n--- Task 2.1: Function to filter readings by location ---")

def get_readings_by_location(readings_list, target_location):
    """
    Filters a list of sensor readings to return only those from a specific location.

    Args:
        readings_list (list): A list of sensor readings, where each reading is a tuple
                              (timestamp_str, device_id, device_type, location, value).
        target_location (str): The location to filter by.

    Returns:
        list: A list of reading tuples that match the target_location.
    """
    filtered_readings = []
    for reading in readings_list:
        # Location is the 4th element (index 3) in the reading tuple
        if reading[3] == target_location:
            filtered_readings.append(reading)
    return filtered_readings

# Example usage:
sample_location = 'Lab1'
lab1_readings = get_readings_by_location(raw_sensor_data, sample_location)

print(f"Readings for {sample_location}:")
for i, reading in enumerate(lab1_readings):
    if i < 5: # Print only the first 5 for brevity
        print(reading)
    elif i == 5:
        print("... (and more) ")
print(f"Total readings found for {sample_location}: {len(lab1_readings)}")

# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
print("\n--- Task 2.2: Function to calculate average temperature ---")

def calculate_average_temperature(temp_data_list):
    """
    Calculates the average temperature from a list of temperature readings.

    Args:
        temp_data_list (list): A list of dictionaries, where each dictionary
                               contains a 'temperature_celsius' key.

    Returns:
        float: The average temperature, or 0.0 if the list is empty.
    """
    if not temp_data_list:
        return 0.0

    total_temperature = sum(reading['temperature_celsius'] for reading in temp_data_list)
    return total_temperature / len(temp_data_list)

# Example usage:
average_temp = calculate_average_temperature(temperature_readings)
print(f"Average temperature from all readings: {average_temp:.2f} °C")

# Example with an empty list
empty_list_avg = calculate_average_temperature([])
print(f"Average temperature from an empty list: {empty_list_avg:.2f} °C")


# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
print("\n--- Task 2.3: Function to generate a formatted report line ---")

def generate_report_line(reading_dict):
    """
    Formats a single temperature reading dictionary into a human-readable string.

    Args:
        reading_dict (dict): A dictionary representing a single temperature reading,
                             with keys 'timestamp', 'device_id', 'location', 'temperature_celsius'.

    Returns:
        str: A formatted string like "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C".
    """
    timestamp = reading_dict['timestamp']
    device_id = reading_dict['device_id']
    location = reading_dict['location']
    temperature = reading_dict['temperature_celsius']
    return f"[{timestamp}] Device {device_id} at {location}: {temperature}°C"

# Example usage:
if temperature_readings:
    sample_temp_reading = temperature_readings[0] # Get the first temperature reading for example
    report_line = generate_report_line(sample_temp_reading)
    print("Sample Report Line:")
    print(report_line)
else:
    print("No temperature readings available to generate a report line.")


# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")


# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
print("\n--- Task 3.3: Generate a list of random integer values ---")

random_values = []
for _ in range(5):
    random_values.append(random.randint(100, 200)) # 100 and 200 are inclusive

print(f"Generated random values: {random_values}")


# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")


# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
print("\n--- Task 4.2: Read report from file ---")

read_report_lines = []
try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("First 3 lines of the read report:")
    for i, line in enumerate(read_report_lines):
        if i < 3:
            print(line.strip()) # .strip() removes newline characters
except FileNotFoundError:
    print(f"Error: The file '{report_filename}' was not found.")
except IOError as e:
    print(f"Error reading file '{report_filename}': {e}")




print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Generated 25 temperature readings.
# First 5 temperature readings:
# {'timestamp': '2026-08-17 09:55:34', 'device_id': 'DEV001', 'location': 'Lab1', 'temperature_celsius': 18.71}
# {'timestamp': '2026-08-17 09:55:34', 'device_id': 'DEV006', 'location': 'Warehouse', 'temperature_celsius': 23.67}
# {'timestamp': '2026-08-17 09:55:34', 'device_id': 'DEV011', 'location': 'OfficeB', 'temperature_celsius': 29.8}
# {'timestamp': '2026-08-17 09:55:34', 'device_id': 'DEV015', 'location': 'Lab1', 'temperature_celsius': 28.49}
# {'timestamp': '2026-08-17 09:55:34', 'device_id': 'DEV016', 'location': 'Lab2', 'temperature_celsius': 25.29}
# Unique locations: {'OfficeB', 'Lab1', 'Warehouse', 'OfficeA', 'Lab2'}
# Number of unique locations: 5
# Device Statistics (min_value, max_value):
#   Temperature_Sensor: Min=18.71, Max=29.80
#   Light_Sensor: Min=144.93, Max=985.94
#   Pressure_Sensor: Min=981.24, Max=1029.67
#   Humidity_Sensor: Min=31.73, Max=78.77
#
# First 10 raw sensor readings:
# ('2026-08-17 09:55:34', 'DEV001', 'Temperature_Sensor', 'Lab1', 18.71)
# ('2026-08-17 09:55:34', 'DEV002', 'Light_Sensor', 'OfficeA', 608.75)
# ('2026-08-17 09:55:34', 'DEV003', 'Pressure_Sensor', 'OfficeB', 1018.65)
# ('2026-08-17 09:55:34', 'DEV004', 'Humidity_Sensor', 'Lab2', 42.92)
# ('2026-08-17 09:55:34', 'DEV005', 'Humidity_Sensor', 'Warehouse', 42.98)
# ('2026-08-17 09:55:34', 'DEV006', 'Temperature_Sensor', 'Warehouse', 23.67)
# ('2026-08-17 09:55:34', 'DEV007', 'Light_Sensor', 'OfficeA', 574.5)
# ('2026-08-17 09:55:34', 'DEV008', 'Humidity_Sensor', 'Warehouse', 50.06)
# ('2026-08-17 09:55:34', 'DEV009', 'Pressure_Sensor', 'OfficeB', 1018.98)
# ('2026-08-17 09:55:34', 'DEV010', 'Humidity_Sensor', 'OfficeB', 33.95)
#
# Device type of the 5th reading: Humidity_Sensor
#
# Temperature value of the second recorded temperature reading: 23.67
#
# Original timestamp: 2026-08-17 09:55:34
# Date part: 2026-08-17
# Time part: 09:55:34
#
# Sliced Readings 1 (10th to 20th inclusive):
# ('2026-08-17 09:55:34', 'DEV010', 'Humidity_Sensor', 'OfficeB', 33.95)
# ('2026-08-17 09:55:34', 'DEV011', 'Temperature_Sensor', 'OfficeB', 29.8)
# ('2026-08-17 09:55:34', 'DEV012', 'Light_Sensor', 'Lab2', 144.93)
# ('2026-08-17 09:55:34', 'DEV013', 'Pressure_Sensor', 'OfficeA', 1006.89)
# ('2026-08-17 09:55:34', 'DEV014', 'Pressure_Sensor', 'Lab1', 1019.4)
# ('2026-08-17 09:55:34', 'DEV015', 'Temperature_Sensor', 'Lab1', 28.49)
# ('2026-08-17 09:55:34', 'DEV016', 'Temperature_Sensor', 'Lab2', 25.29)
# ('2026-08-17 09:55:34', 'DEV017', 'Humidity_Sensor', 'OfficeA', 48.31)
# ('2026-08-17 09:55:34', 'DEV018', 'Temperature_Sensor', 'OfficeB', 21.07)
# ('2026-08-17 09:55:34', 'DEV019', 'Pressure_Sensor', 'Lab1', 1026.32)
# ('2026-08-17 09:55:34', 'DEV020', 'Humidity_Sensor', 'OfficeB', 31.73)
# ('2026-08-17 09:55:34', 'DEV021', 'Light_Sensor', 'OfficeB', 258.98)
#
# Sliced Readings 2 (every 5th reading):
# ('2026-08-17 09:55:34', 'DEV001', 'Temperature_Sensor', 'Lab1', 18.71)
# ('2026-08-17 09:55:34', 'DEV006', 'Temperature_Sensor', 'Warehouse', 23.67)
# ('2026-08-17 09:55:34', 'DEV011', 'Temperature_Sensor', 'OfficeB', 29.8)
# ('2026-08-17 09:55:34', 'DEV016', 'Temperature_Sensor', 'Lab2', 25.29)
# ('2026-08-17 09:55:34', 'DEV021', 'Light_Sensor', 'OfficeB', 258.98)
# ('2026-08-17 09:55:34', 'DEV026', 'Pressure_Sensor', 'Warehouse', 1006.2)
# ('2026-08-17 09:55:34', 'DEV031', 'Temperature_Sensor', 'Warehouse', 29.07)
# ('2026-08-17 09:55:34', 'DEV036', 'Pressure_Sensor', 'Lab1', 995.25)
# ('2026-08-17 09:55:34', 'DEV041', 'Pressure_Sensor', 'OfficeB', 988.73)
# ('2026-08-17 09:55:34', 'DEV046', 'Humidity_Sensor', 'OfficeB', 41.32)
# ('2026-08-17 09:55:34', 'DEV051', 'Pressure_Sensor', 'OfficeA', 1009.37)
# ('2026-08-17 09:55:34', 'DEV056', 'Light_Sensor', 'Lab1', 573.09)
# ('2026-08-17 09:55:34', 'DEV061', 'Light_Sensor', 'Lab2', 236.68)
# ('2026-08-17 09:55:34', 'DEV066', 'Pressure_Sensor', 'Warehouse', 988.71)
# ('2026-08-17 09:55:34', 'DEV071', 'Temperature_Sensor', 'Lab2', 19.13)
# ('2026-08-17 09:55:34', 'DEV076', 'Temperature_Sensor', 'Lab1', 28.17)
# ('2026-08-17 09:55:34', 'DEV081', 'Pressure_Sensor', 'Lab2', 990.93)
# ('2026-08-17 09:55:34', 'DEV086', 'Pressure_Sensor', 'Lab1', 985.92)
# ('2026-08-17 09:55:34', 'DEV091', 'Pressure_Sensor', 'Warehouse', 991.59)
# ('2026-08-17 09:55:34', 'DEV096', 'Pressure_Sensor', 'Lab1', 1023.52)
#
# Original string: 'Python Programming is fun and powerful.'
# Extracted 'Programming': 'Programming'
# Extracted reversed 'Python' ('nohtyP'): 'nohtyP'
#
# Device type of the 5th reading (from previous step): Humidity_Sensor
# Extracted device type suffix: 'Sensor'
#
# --- Task 2: Function Definitions and Usage ---
#
# --- Task 2.1: Function to filter readings by location ---
# Readings for Lab1:
# ('2026-08-17 09:55:34', 'DEV001', 'Temperature_Sensor', 'Lab1', 18.71)
# ('2026-08-17 09:55:34', 'DEV014', 'Pressure_Sensor', 'Lab1', 1019.4)
# ('2026-08-17 09:55:34', 'DEV015', 'Temperature_Sensor', 'Lab1', 28.49)
# ('2026-08-17 09:55:34', 'DEV019', 'Pressure_Sensor', 'Lab1', 1026.32)
# ('2026-08-17 09:55:34', 'DEV023', 'Light_Sensor', 'Lab1', 250.2)
# ... (and more)
# Total readings found for Lab1: 21
#
# --- Task 2.2: Function to calculate average temperature ---
# Average temperature from all readings: 24.63 °C
# Average temperature from an empty list: 0.00 °C
#
# --- Task 2.3: Function to generate a formatted report line ---
# Sample Report Line:
# [2026-08-17 09:55:34] Device DEV001 at Lab1: 18.71°C
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.
#
# Duration of data collection: 0 days, 0 hours, 0 minutes.
#
# --- Task 3.3: Generate a list of random integer values ---
# Generated random values: [130, 177, 111, 185, 147]
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# --- Task 4.2: Read report from file ---
# First 3 lines of the read report:
# [2026-08-17 09:55:34] Device DEV001 at Lab1: 18.71°C
# [2026-08-17 09:55:34] Device DEV006 at Warehouse: 23.67°C
# [2026-08-17 09:55:34] Device DEV011 at OfficeB: 29.8°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
