# %%
import pandas as pd
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print("\nSeries:")
print(s)
data = {
    'Name': ['rahul', 'ravi', 'Charan', 'akhil'],
    'Age': [25, 30, 35, 40],
    'Salary': [50000, 60000, 70000, 80000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# Series:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
#
# DataFrame:
#      Name  Age  Salary
# 0   rahul   25   50000
# 1    ravi   30   60000
# 2  Charan   35   70000
# 3   akhil   40   80000

# %%
import numpy as np
import pandas as pd
array = np.array([[1, 2], [3, 4], [5, 6]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
In [ ]:

from functools import reduce
numbers = list(map(int, input("Enter the list of elements: ").split()))
squared = list(map(lambda x: x ** 2, numbers))
even_numbers = list(filter(lambda x: x % 2 == 0, squared))
sum_even = reduce(lambda x, y: x + y, even_numbers, 0)

print(f"Original List : {numbers}")
print(f"Squared List  : {squared}")
print(f"Even Squares  : {even_numbers}")
print(f"Sum of Even Squares : {sum_even}")
print(df_from_array)
# Out:
# DataFrame from NumPy array:
#    Column1  Column2
# 0        1        2
# 1        3        4
# 2        5        6

# %%
print("\nRow with label 1 using loc:")
print(df.loc[1])
In [ ]:

from functools import reduce
numbers = list(map(int, input("Enter the list of elements: ").split()))
squared = list(map(lambda x: x ** 2, numbers))
even_numbers = list(filter(lambda x: x % 2 == 0, squared))
sum_even = reduce(lambda x, y: x + y, even_numbers, 0)

print(f"Original List : {numbers}")
print(f"Squared List  : {squared}")
print(f"Even Squares  : {even_numbers}")
print(f"Sum of Even Squares : {sum_even}")
# Out:
# Row with label 1 using loc:
# Name        Bob
# Age          30
# Salary    60000
# Name: 1, dtype: object

# %%
print("\nFirst two rows using iloc:")
print(df.iloc[0:2])
# Out:
# First two rows using iloc:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000

# %%
print("\nSelect 'Name' column:")
print(df['Name'])

print("\nSelect 'Name' and 'Age' colum
In [ ]:

from functools import reduce
numbers = list(map(int, input("Enter the list of elements: ").split()))
squared = list(map(lambda x: x ** 2, numbers))
even_numbers = list(filter(lambda x: x % 2 == 0, squared))
sum_even = reduce(lambda x, y: x + y, even_numbers, 0)

print(f"Original List : {numbers}")
print(f"Squared List  : {squared}")
print(f"Even Squares  : {even_numbers}")
print(f"Sum of Even Squares : {sum_even}")ns:")
print(df[['Name', 'Age']])

print("\nRows where Salary > 60000:")
print(df[df['Salary'] > 60000])
# Out:
# Select 'Name' column:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
#
# Rows where Salary > 60000:
#       Name  Age  Salary
# 2  Charlie   35   70000
# 3    David   40   80000

# %%
data={
    'Name':['Pink','Green',None,'Yellow'],
    'Age':[25,None,35, 40],
    'Salary':[50000, 70000, None, 90000]
}
data = pd.DataFrame(data)
print("\nOriginal Dirty DataFrame:")
print(data)
# Out:
# Original Dirty DataFrame:
#      Name   Age   Salary
# 0    Pink  25.0  50000.0
# 1   Green   NaN  70000.0
# 2    None  35.0      NaN
# 3  Yellow  40.0  90000.0

# %%
print("\nDrop rows with any NaN values:")
print(data.dropna())

print("\nFill missing values with a specific value:")
print(data.fillna({'Name': 'Unknown', 'Age': data['Age'].mean(), 'Salary': 0}))
# Out:
# Drop rows with any NaN values:
#      Name   Age   Salary
# 0    Pink  25.0  50000.0
# 3  Yellow  40.0  90000.0
#
# Fill missing values with a specific value:
#       Name        Age   Salary
# 0     Pink  25.000000  50000.0
# 1    Green  33.333333  70000.0
# 2  Unknown  35.000000      0.0
# 3   Yellow  40.000000  90000.0

# %%
print("\nBoolean DataFrame for missing values:")
print(data.isnull())
In [ ]:

from functools import reduce
numbers = list(map(int, input("Enter the list of elements: ").split()))
squared = list(map(lambda x: x ** 2, numbers))
even_numbers = list(filter(lambda x: x % 2 == 0, squared))
sum_even = reduce(lambda x, y: x + y, even_numbers, 0)

print(f"Original List : {numbers}")
print(f"Squared List  : {squared}")
print(f"Even Squares  : {even_numbers}")
print(f"Sum of Even Squares : {sum_even}")
# Out:
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False

# %%
df['Bonus'] = df['Salary'] * 0.1
print("\nDataFrame with Bonus column:")
print(df)

print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
In [ ]:

from functools import reduce
numbers = list(map(int, input("Enter the list of elements: ").split()))
squared = list(map(lambda x: x ** 2, numbers))
even_numbers = list(filter(lambda x: x % 2 == 0, squared))
sum_even = reduce(lambda x, y: x + y, even_numbers, 0)

print(f"Original List : {numbers}")
print(f"Squared List  : {squared}")
print(f"Even Squares  : {even_numbers}")
print(f"Sum of Even Squares : {sum_even}")

print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))

print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# DataFrame with Bonus column:
#       Name  Age  Salary   Bonus
# 0    Alice   25   50000  5000.0
# 1      Bob   30   60000  6000.0
# 2  Charlie   35   70000  7000.0
# 3    David   40   80000  8000.0
#
# Rename columns:
#       Name  Age  BaseSalary   Bonus
# 0    Alice   25       50000  5000.0
# 1      Bob   30       60000  6000.0
# 2  Charlie   35       70000  7000.0
# 3    David   40       80000  8000.0
#
# Sort by Age descending:
#       Name  Age  Salary   Bonus
# 3    David   40   80000  8000.0
# 2  Charlie   35   70000  7000.0
# 1      Bob   30   60000  6000.0
# 0    Alice   25   50000  5000.0
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    55000.0
# True     75000.0
# Name: Salary, dtype: float64

# %%
print("\nRename columns:")
df_renamed = df.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
# Out:
# Rename columns:
#       Name  Age  BaseSalary   Bonus  AgeGroup
# 0    Alice   25       50000  5000.0     False
# 1      Bob   30       60000  6000.0     False
# 2  Charlie   35       70000  7000.0      True
# 3    David   40       80000  8000.0      True

# %%
print("\nSort by Age descending:")
print(df.sort_values(by='Age', ascending=False))

print("\nGroup by operation (average salary by age > 30 or not):")
df['AgeGroup'] = df['Age'] > 30
print(df.groupby('AgeGroup')['Salary'].mean())
# Out:
# Sort by Age descending:
#       Name  Age  Salary   Bonus  AgeGroup
# 3    David   40   80000  8000.0      True
# 2  Charlie   35   70000  7000.0      True
# 1      Bob   30   60000  6000.0     False
# 0    Alice   25   50000  5000.0     False
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    55000.0
# True     75000.0
# Name: Salary, dtype: float64

# %%
import numpy as np
import pandas as pd
np.random.seed(1)
num_rows = 10
df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})

print("\nSynthetic DataFrame:")
print(df_synth)
# Out:
# Synthetic DataFrame:
#    ID  Score  Passed
# 0   1     87   False
# 1   2     93    True
# 2   3     62   False
# 3   4     58   False
# 4   5     59    True
# 5   6     61    True
# 6   7     55   False
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True

# %%
print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])

print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())
# Out:
# Students who passed:
#    ID  Score  Passed
# 1   2     93    True
# 4   5     59    True
# 5   6     61    True
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True
#
# Average score of failed students:
# 65.5
